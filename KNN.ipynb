# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv ('/fertility_Diagnosis.csv')
df.head(5)
# Out:
#    temporada  idade  doencas_infantis  acidente  cirurgia  febre  alcool  \
# 0      -0.33   0.69                 0         1         1      0     0.8
# 1      -0.33   0.94                 1         0         1      0     0.8
# 2      -0.33   0.50                 1         0         0      0     1.0
# 3      -0.33   0.75                 0         1         1      0     1.0
# 4      -0.33   0.67                 1         1         0      0     0.8
#
#    fumo  sentado classe
# 0     0     0.88      N
# 1     1     0.31      O
# 2    -1     0.50      N
# 3    -1     0.38      N
# 4    -1     0.50      O

# %%
df.tail(10)
# Out:
#     temporada  idade  doencas_infantis  acidente  cirurgia  febre  alcool  \
# 90      -0.33   0.81                 1         1         1      1     0.8
# 91       0.33   0.78                 1         0         0      0     1.0
# 92       0.33   0.75                 1         1         0      0     0.8
# 93       0.33   0.75                 1         0         1      0     0.8
# 94       1.00   0.58                 1         0         0      0     0.6
# 95      -1.00   0.67                 1         0         0      0     1.0
# 96      -1.00   0.61                 1         0         0      0     0.8
# 97      -1.00   0.67                 1         1         1      0     1.0
# 98      -1.00   0.64                 1         0         1      0     1.0
# 99      -1.00   0.69                 0         1         1      0     0.6
#
#     fumo  sentado classe
# 90    -1     0.38      N
# 91     1     0.06      N
# 92    -1     0.38      N
# 93    -1     0.44      O
# ...

# %%
df['classe'] = df['classe'].replace('N', 1).replace('O', 0)
df
# Out:
# <ipython-input-68-4019ab707ea8>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['classe'] = df['classe'].replace('N', 1).replace('O', 0)
#     temporada  idade  doencas_infantis  acidente  cirurgia  febre  alcool  \
# 0       -0.33   0.69                 0         1         1      0     0.8
# 1       -0.33   0.94                 1         0         1      0     0.8
# 2       -0.33   0.50                 1         0         0      0     1.0
# 3       -0.33   0.75                 0         1         1      0     1.0
# 4       -0.33   0.67                 1         1         0      0     0.8
# ..        ...    ...               ...       ...       ...    ...     ...
# 95      -1.00   0.67                 1         0         0      0     1.0
# ...

# %%
#One not, normaliza, padroniza.....

def normalizar(x):
  return (x - np.min(x))/(np.max(x) - np.min(x))

def padronizar(x):
  return (x - np.mean(x))/np.std(x)



from scipy.stats import shapiro
#Verificar normalidade usando o teste de shapiro-wilk
def verifica_normalidade(dataframe, coluna):
    coluna_data = dataframe[coluna]
    # Realizar o teste de shapiro-wilk
    statistic, p_valor = shapiro(coluna_data)
    #definir o nível de significancia
    nivel_significancia = 0.05
    #Verificar se a hipótese nula de normalidade pode ser rejeitada
    if p_valor > nivel_significancia:
      print(f"A coluna '{coluna}' segue uma distribuição normal")
      return True
    else:
      print(f"A coluna '{coluna}' não segue uma distribuição normal")
      return False

# %%
df.columns
# Out:
# Index(['temporada', 'idade', 'doencas_infantis', 'acidente', 'cirurgia',
#        'febre', 'alcool', 'fumo', 'sentado', 'classe'],
#       dtype='object')

# %%
df = pd.get_dummies(df, columns=['temporada', 'doencas_infantis','acidente','cirurgia','febre', 'alcool','fumo'])
df
# Out:
#     idade  sentado  classe  temporada_-1.0  temporada_-0.33  temporada_0.33  \
# 0    0.69     0.88       1           False             True           False
# 1    0.94     0.31       0           False             True           False
# 2    0.50     0.50       1           False             True           False
# 3    0.75     0.38       1           False             True           False
# 4    0.67     0.50       0           False             True           False
# ..    ...      ...     ...             ...              ...             ...
# 95   0.67     0.50       1            True            False           False
# 96   0.61     0.50       1            True            False           False
# 97   0.67     0.31       1            True            False           False
# 98   0.64     0.19       1            True            False           False
# 99   0.69     0.19       1            True            False           False
#
# ...

# %%
y = df['classe']
#x = df.drop('classe', axis=1)
X = df.drop(columns=['classe'])

# %%
X
# Out:
#     idade  sentado  temporada_-1.0  temporada_-0.33  temporada_0.33  \
# 0    0.69     0.88           False             True           False
# 1    0.94     0.31           False             True           False
# 2    0.50     0.50           False             True           False
# 3    0.75     0.38           False             True           False
# 4    0.67     0.50           False             True           False
# ..    ...      ...             ...              ...             ...
# 95   0.67     0.50            True            False           False
# 96   0.61     0.50            True            False           False
# 97   0.67     0.31            True            False           False
# 98   0.64     0.19            True            False           False
# 99   0.69     0.19            True            False           False
#
#     temporada_1.0  doencas_infantis_0  doencas_infantis_1  acidente_0  \
# 0           False                True               False       False
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
y_train
# Out:
# 73    1
# 56    1
# 7     1
# 8     1
# 50    1
#      ..
# 98    1
# 33    1
# 27    0
# 31    1
# 6     1
# Name: classe, Length: 70, dtype: int64

# %%
X_train
# Out:
#     idade  sentado  temporada_-1.0  temporada_-0.33  temporada_0.33  \
# 73   0.50     0.44            True            False           False
# 56   0.53     0.75           False             True           False
# 7    1.00     0.38           False             True           False
# 8    0.64     0.25           False            False           False
# 50   0.67     0.19           False             True           False
# ..    ...      ...             ...              ...             ...
# 98   0.64     0.19            True            False           False
# 33   0.58     0.44           False            False           False
# 27   0.78     0.38           False            False           False
# 31   0.56     0.44           False            False           False
# 6    0.67     0.44           False             True           False
#
#     temporada_1.0  doencas_infantis_0  doencas_infantis_1  acidente_0  \
# 73          False               False                True        True
# ...

# %%
k = 3
model = KNeighborsClassifier(n_neighbors=k)
model.fit(X_train, y_train)
print(k, model.score(X_test, y_test))
# Out:
# 3 0.8333333333333334

# %%
for k in range(1, 10):
  model = KNeighborsClassifier(n_neighbors=k)

  model.fit(X_train, y_train )
  print(k, model.score(X_test, y_test))
# Out:
# 1 0.8666666666666667
# 2 0.8
# 3 0.8333333333333334
# 4 0.8333333333333334
# 5 0.8666666666666667
# 6 0.8666666666666667
# 7 0.8666666666666667
# 8 0.8666666666666667
# 9 0.8666666666666667

# %% [markdown]
# **Predict**

# %%
print(f"Classe prevista: {model.predict(X_test[-1:])}")
print("Classe real:")
y_test.tail(1)
# Out:
# Classe prevista: [1]
# Classe real:
# 22    1
# Name: classe, dtype: int64
